# %%
import seaborn as sns #this is the plotting library I'll be using 
import pandas as pd #"as pd" means that we can use the abbreviation in commands
import matplotlib.pyplot as plt #we need Matplotlib for setting the labels in the Seaborn graphs

df1 = pd.read_csv('steps.csv', sep=';')
df1.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  4-5-2014  5-5-2014  6-5-2014  \
# 0     9929.0    12879.0    10541.0  ...       NaN       NaN       NaN
# 1     4024.0     3926.0    14595.0  ...       NaN       NaN       NaN
# 2     8185.0     9630.0     8983.0  ...    3914.0    4364.0       NaN
# 3        NaN        NaN        NaN  ...       NaN       NaN       NaN
# 4        NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#    7-5-2014  8-5-2014  9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014
# ...

# %%
df2 = pd.read_csv('survey.csv')
df2.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight
# 0   178.0    98.0
# 1   180.0    77.0
# 2   180.0    83.0
# 3   178.0    80.0
# 4   167.0    61.0

# %%
dfmer = pd.merge(df1, df2, on = 'id') #'id' is the common identifier
dfmer.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  12-5-2014  13-5-2014         city  \
# 0     9929.0    12879.0    10541.0  ...        NaN        NaN     Bordeaux
# 1     4024.0     3926.0    14595.0  ...        NaN        NaN        Lille
# 2     8185.0     9630.0     8983.0  ...     1129.0        NaN  Montpellier
# 3        NaN        NaN        NaN  ...        NaN        NaN         Lyon
# 4        NaN        NaN        NaN  ...        NaN        NaN  Montpellier
#
#    gender    age  hh_size  education          education_1  height  weight
# ...

# %%
dfmer['weight'].value_counts().sort_values()
# Out:
# 6.0       1
# 105.0     1
# 99.0      1
# 149.0     1
# 100.0     1
#          ..
# 55.0     31
# 80.0     31
# 73.0     32
# 65.0     35
# 72.0     40
# Name: weight, Length: 72, dtype: int64

# %%
# The handy Pandas function to_numeric converts non-numeric data to NaN. The last argument overrides the errors
# Python would normally generate.
# The apply method of a dataframe lets us apply a function to all the elements.
dfmer['weight'] = dfmer['weight'].apply(pd.to_numeric, errors='coerce')

#To remove the values above 170.0 and below 40.0 we need to create a function that we then apply to the entire column
def filterweight(x):
    if(x < 170.0 and x > 40 ): 
        return x
    else: 
        return float('NaN')
    
dfmer['weight'] = dfmer['weight'].apply(filterweight)
dfmer.info()
dfmer.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 929 entries, 0 to 928
# Columns: 337 entries, id to weight
# dtypes: float64(330), int64(3), object(4)
# memory usage: 2.4+ MB
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  12-5-2014  13-5-2014         city  \
# 0     9929.0    12879.0    10541.0  ...        NaN        NaN     Bordeaux
# 1     4024.0     3926.0    14595.0  ...        NaN        NaN        Lille
# 2     8185.0     9630.0     8983.0  ...     1129.0        NaN  Montpellier
# ...

# %%
a = dfmer

# %%
a.where(a["city"] == "Montpellier")  #filtering the columns to narrow my investigation
# Out:
#         id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0      NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1      NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2      3.0        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3      NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 4      5.0        NaN        NaN        NaN        NaN        NaN        NaN
# ..     ...        ...        ...        ...        ...        ...        ...
# 924    NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 925    NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 926  927.0        NaN        NaN        NaN     1623.0        NaN        NaN
# 927    NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 928    NaN        NaN        NaN        NaN        NaN        NaN        NaN
#
# ...

# %%
a.where((a["gender"]=="Female") & (a["city"] == "Lille")).dropna(how="all") #filtering the columns to narrow my investigation
# Out:
#         id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 8      9.0        NaN        NaN        NaN        NaN        NaN        NaN
# 9     10.0        NaN        NaN        NaN        NaN        NaN        NaN
# 14    15.0        NaN        NaN        NaN        NaN        NaN        NaN
# 19    20.0        NaN        NaN        NaN        NaN        NaN        NaN
# 26    27.0        NaN     2213.0    26231.0    40392.0     6559.0        NaN
# ..     ...        ...        ...        ...        ...        ...        ...
# 912  913.0        NaN     7512.0     7186.0     4611.0    10464.0    11197.0
# 915  916.0        NaN     8667.0    10471.0      659.0    12079.0     5212.0
# 920  921.0        NaN        NaN        NaN        NaN        NaN        NaN
# 924  925.0        NaN     4571.0    10471.0     5899.0    15295.0     9178.0
# 927  928.0        NaN        NaN    14411.0    14364.0    26629.0    13092.0
#
# ...

# %%
b = a[((a["gender"]=="Female") & (a["city"] == "Lille"))]

# %%
femaleatlille = b
mean_size = b['height'].mean()
mean_size #the mean of the females' weights in Lille are 164.33
# Out:
# 164.3320158102767

# %%
femaleatlille = b
mean_size = b['weight'].mean()
mean_size #the mean of the females' weights in Lille are 64.39 kg
# Out:
# 64.38955823293173

# %%
plt.hist(b['height'])
plt.title("HEIGHTS OF FEMALES AT LILLE")
plt.xlabel("HEIGHT")
plt.ylabel('FEMALES')
# Out:
# Text(0, 0.5, 'FEMALES')

# %%
sns.distplot(b['weight'], kde = True)
plt.title(' WEIGHTS OF FEMALES AT LILLE')
plt.xlabel('KG')
# Out:
# Text(0.5, 0, 'KG')
